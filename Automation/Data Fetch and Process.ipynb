# %%
# imports
import selenium
from selenium import webdriver
from selenium.webdriver import ActionChains
from selenium.webdriver.common.keys import Keys
import time
driver = webdriver.Chrome('./chromedriver')
import pandas as pd
import glob
import os.path
import json

# %%
def Upload_Data_as_JSON(URL, New_Name):
    # add country name
    country_name = 'United Arab Emirates'

    time.sleep(2)
    #Reads the URL 
    driver.get(URL)

    #Waits till the page loads
    time.sleep(60)

    #finds the download button
    s=driver.find_element_by_xpath('/html/body/div/div/div/div[1]/header/div/div/div[2]/div/div[1]/div/button/span[1]/div')

    time.sleep(10)

    s.click()

    #Choose to export the data as excel
    c=driver.find_element_by_xpath('/html/body/div/div/div/div[1]/header/div/div/div[2]/div/div[1]/div[2]/div[2]/div[2]/li[2]/span[1]')

    time.sleep(10)

    c.click()

    print('Downloading Data')

    time.sleep(60)

    #Specify where the data usually loads and choose the last downloaded file
    folder_path = '../../../../Downloads/'

    file_type = '/*xlsx'
    files = glob.glob(folder_path + file_type)
    max_file = max(files, key=os.path.getctime)


    #Saving the data as dic instead of excel

    df = pd.read_excel(max_file)
    df = df.rename(lambda x: 'Country' if any(k in x for k in ['Country Name', 'Reporter', 'Country ']) else x, axis=1)
    df = df[df['Country'] == country_name]
    df = df.where(pd.notnull(df), None)
    import_file = df.to_dict(orient='records')
    print (import_file)
    
    #Save the file as a json with the name you specified
    with open(New_Name+ '.json', 'w') as fp:
        json.dump(import_file, fp)
    
    return import_file

# %%
#Add the URLs
URLs=[
#     'https://data.unescwa.org/portal/c78f8929-babc-40d9-8d9b-a5438396d3a7', #National Accounts
#     'https://data.unescwa.org/portal/37e07376-dcab-4c77-b25d-b63c6c1c0d4b', #Finance
#     'https://data.unescwa.org/portal/a2f766e6-f2c0-4444-aa73-ccd0d7abf05d', #Trade
#     'https://data.unescwa.org/portal/79a73daa-8d9e-47dd-b1ee-bfed2b22124e', #Transport
#     'https://data.unescwa.org/portal/ae81b7b7-05b5-4b39-b87a-1243bef7b232', #Industry
#     'https://data.unescwa.org/portal/CPI',                                  #CPI
#     'https://data.unescwa.org/portal/a400b071-fd51-4aac-87ae-175627339bdd', #ICP
#     'https://data.unescwa.org/portal/gems_data',                            #GEMS
    'https://data.unescwa.org/portal/7bae8f12-f543-407f-9afa-29471d6b7c6d', #Population
    'https://data.unescwa.org/portal/e68647fb-ea6d-488d-a6f5-2024b080c2cc', #Household Budget
    'https://data.unescwa.org/portal/8c972cac-a80c-4bd4-8208-74c6a092e225', #Health
    'https://data.unescwa.org/portal/e7d41253-2cf5-4f3b-ba5f-6c45b8af1f88', #Education
    'https://data.unescwa.org/portal/69b86687-53d8-4c50-b5d7-b6c96df42d0b', #Labor
    'https://data.unescwa.org/portal/e28b867b-13b6-4d97-ad5e-85264879c2ef', #Environment
    'https://data.unescwa.org/portal/ed5c2876-01e0-492b-9fad-49702ec6d934' #Energy
#     'https://data.unescwa.org/share/618997eb-93eb-466c-b768-50557b5ae7b2' #SDG

    ]

#Names of the new saved data

Names=[
#     'National Accounts',
#     'Finance',
#     'Trade',
#     'Transport',
#     'Industry',
#     'CPI',
#     'ICP',
#     'GEMS',
    'Population',
    'Household Budget',
    'Health',
    'Education',
    'Labor',
    'Environment',
    'Energy'
#     'SDG'

    
    ]

   
for i in range(len(URLs)):
    print("Starting with Document: " ,i)
    Upload_Data_as_JSON(URLs[i], Names[i])
    print("Finished document: " , i)
# Out:
# Starting with Document:  0
# Downloading Data
# /Users/malabdal/opt/anaconda3/lib/python3.8/site-packages/openpyxl/styles/stylesheet.py:214: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# [{'Indicator': 'Population size (number)', 'Country': 'United Arab Emirates', 'Age': '0-4 years', 'Sex': 'Both sexes', 'Area': 'Area Total', 'Nationality': 'Nationality Total', 'Marital status': 'Marital status NA', 'Causes of death': 'Causes of death NA', '2000': None, '2001': None, '2002': None, '2003': None, '2004': None, '2005': 282139.0, '2006': None, '2007': None, '2008': None, '2009': None, '2010': None, '2011': None, '2012': None, '2013': None, '2014': None, '2015': None, '2016': None, '2017': None, '2018': None, '2019': None}, {'Indicator': 'Population size (number)', 'Country': 'United Arab Emirates', 'Age': '0-4 years', 'Sex': 'Both sexes', 'Area': 'Area Total', 'Nationality': 'Nationals', 'Marital status': 'Marital status NA', 'Causes of death': 'Causes of death NA', '2000': None, '2001': None, '2002': None, '2003': None, '2004': None, '2005': 107430.0, '2006': None, '2007': None, '2008': None, '2009': None, '2010': None, '2011': None, '2012': None, '2013': None, '2014': None, '2015': None, '2016': None, '2017': None, '2018': None, '2019': None}, {'Indicator': 'Population size (number)', 'Country': 'United Arab Emirates', 'Age': '0-4 years', 'Sex': 'Both sexes', 'Area': 'Area Total', 'Nationality': 'Non-nationals', 'Marital status': 'Marital status NA', 'Causes of death': 'Causes of death NA', '2000': None, '2001': None, '2002': None, '2003': None, '2004': None, '2005': 174709.0, '2006': None, '2007': None, '2008': None, '2009': None, '2010': None, '2011': None, '2012': None, '2013': None, '2014': None, '2015': None, '2016': None, '2017': None, '2018': None, '2019': None}, {'Indicator': 'Population size (number)', 'Country': 'United Arab Emirates', 'Age': '0-4 years', 'Sex': 'Female', 'Area': 'Area Total', 'Nationality': 'Nationality Total', 'Marital status': 'Marital status NA', 'Causes of death': 'Causes of death NA', '2000': None, '2001': None, '2002': None, '2003': None, '2004': None, '2005': 136538.0, '2006': None, '2007': None, '2008': None, '2009': None, '2010': None, '2011': None, '2012': None, '2013': None, '2014': None, '2015': None, '2016': None, '2017': None, '2018': None, '2019': None}, {'Indicator': 'Population size (number)', 'Country': 'United Arab Emirates', 'Age': '0-4 years', 'Sex': 'Female', 'Area': 'Area Total', 'Nationality': 'Nationals', 'Marital status': 'Marital status NA', 'Causes of death': 'Causes of death NA', '2000': None, '2001': None, '2002': None, '2003': None, '2004': None, '2005': 52310.0, '2006': None, '2007': None, '2008': None, '2009': None, '2010': None, '2011': None, '2012': None, '2013': None, '2014': None, '2015': None, '2016': None, '2017': None, '2018': None, '2019': None}, {'Indicator': 'Population size (number)', 'Country': 'United Arab Emirates', 'Age': '0-4 years', 'Sex': 'Female', 'Area': 'Area Total', 'Nationality': 'Non-nationals', 'Marital status': 'Marital status NA', 'Causes of death': 'Causes of death NA', '2000': None, '2001': None, '2002': None, '2003': None, '2004': None, '2005': 84228.0, '2006': None, '2007': None, '2008': None, '2009': None, '2010': None, '2011': None, '2012': None, '2013': None, '2014': None, '2015': None, '2016': None, '2017': None, '2018': None, '2019': None}, {'Indicator': 'Population size (number)', 'Country': 'United Arab Emirates', 'Age': '0-4 years', 'Sex': 'Male', 'Area': 'Area Total', 'Nationality': 'Nationality Total', 'Marital status': 'Marital status NA', 'Causes of death': 'Causes of death NA', '2000': None, '2001': None, '2002': None, '2003': None, '2004': None, '2005': 145601.0, '2006': None, '2007': None, '2008': None, '2009': None, '2010': None, '2011': None, '2012': None, '2013': None, '2014': None, '2015': None, '2016': None, '2017': None, '2018': None, '2019': None}, {'Indicator': 'Population size (number)', 'Country': 'United Arab Emirates', 'Age': '0-4 years', 'Sex': 'Male', 'Area': 'Area Total', 'Nationality': 'Nationals', 'Marital status': 'Marital status NA', 'Causes of death': 'Causes of death NA', '2000': None,  ...
# Finished document:  0
# Starting with Document:  1
# Downloading Data
# [{'Indicator': 'Multi-dimensional Poverty index', 'Country': 'United Arab Emirates', 'Age': 'Age not available', 'Sex': 'Sex NA', 'Area': 'Area NA', 'Nationality': 'Nationality NA', 'Quintile': 'Quintile NA', 'Types of products/services': 'Products and services NA', '2000': None, '2001': None, '2002': None, '2003': 0.0020124, '2004': None, '2005': None, '2006': None, '2007': None, '2008': None, '2009': None, '2010': None, '2011': None, '2012': None, '2013': None, '2014': None, '2015': None, '2016': None, '2017': None, '2018': None, '2019': None, '2020': None}, {'Indicator': 'Poverty headcount ratio at $1.90 a day (2011 PPP) (% of population)', 'Country': 'United Arab Emirates', 'Age': 'Age not available', 'Sex': 'Sex NA', 'Area': 'Area NA', 'Nationality': 'Nationality NA', 'Quintile': 'Quintile NA', 'Types of products/services': 'Products and services NA', '2000': None, '2001': None, '2002': None, '2003': None, '2004': None, '2005': None, '2006': None, '2007': None, '2008': None, '2009': None, '2010': None, '2011': None, '2012': None, '2013': 0.0, '2014': None, '2015': None, '2016': None, '2017': None, '2018': 0.0, '2019': None, '2020': None}]
# Finished document:  1
# Starting with Document:  2
# Downloading Data
# [{'Indicator': 'Maternal mortality ratio (per 100,000 live births)', 'Country': 'United Arab Emirates', 'Age': 'Age not available', 'Sex': 'Sex NA', 'Area': 'Area Total', 'Nationality': 'Nationality Total', 'Immunization': 'Immunization NA', 'Contraception method': 'Method NA', '2000': 0.0, '2001': 3.6, '2002': 3.4, '2003': 6.5, '2004': 0.0, '2005': 0.0, '2006': 0.0, '2007': 0.0, '2008': 0.0, '2009': 1.3, '2010': 3.8, '2011': 3.6, '2012': 2.2, '2013': 3.2, '2014': 3.1, '2015': 2.1, '2016': 3.1, '2017': 2.0, '2018': 2.1, '2019': 2.30438201204146, '2020': 2.31487677635431}, {'Indicator': 'Births attended by skilled health personnel (percent)', 'Country': 'United Arab Emirates', 'Age': 'Age not available', 'Sex': 'Sex NA', 'Area': 'Area Total', 'Nationality': 'Nationality Total', 'Immunization': 'Immunization NA', 'Contraception method': 'Method NA', '2000': 98.5, '2001': None, '2002': None, '2003': None, '2004': 99.9, '2005': None, '2006': None, '2007': None, '2008': None, '2009': 99.9, '2010': 99.0, '2011': 99.0, '2012': 99.0, '2013': 99.0, '2014': 99.0, '2015': 99.0, '2016': 100.0, '2017': 100.0, '2018': 100.0, '2019': 100.0, '2020': 100.0}, {'Indicator': 'Antenatal care (percent)', 'Country': 'United Arab Emirates', 'Age': 'Age not available', 'Sex': 'Sex NA', 'Area': 'Area Total', 'Nationality': 'Nationality Total', 'Immunization': 'Immunization NA', 'Contraception method': 'Method NA', '2000': None, '2001': None, '2002': None, '2003': None, '2004': None, '2005': None, '2006': None, '2007': 100.0, '2008': None, '2009': None, '2010': 100.0, '2011': 100.0, '2012': 100.0, '2013': 100.0, '2014': 100.0, '2015': 100.0, '2016': 100.0, '2017': 100.0, '2018': None, '2019': 100.0, '2020': 100.0}, {'Indicator': 'Immunization coverage rate (percent)', 'Country': 'United Arab Emirates', 'Age': 'Age not available', 'Sex': 'Both sexes', 'Area': 'Area Total', 'Nationality': 'Nationality Total', 'Immunization': 'BCG immunization', 'Contraception method': 'Method NA', '2000': None, '2001': None, '2002': None, '2003': None, '2004': None, '2005': None, '2006': None, '2007': None, '2008': None, '2009': None, '2010': 98.0, '2011': 98.0, '2012': 98.0, '2013': 98.0, '2014': 98.0, '2015': 98.0, '2016': 98.0, '2017': 98.0, '2018': 100.0, '2019': 98.8116021632186, '2020': 98.8298692006836}, {'Indicator': 'Immunization coverage rate (percent)', 'Country': 'United Arab Emirates', 'Age': 'Age not available', 'Sex': 'Both sexes', 'Area': 'Area Total', 'Nationality': 'Nationality Total', 'Immunization': 'DPT immunization', 'Contraception method': 'Method NA', '2000': None, '2001': None, '2002': None, '2003': None, '2004': None, '2005': None, '2006': None, '2007': None, '2008': None, '2009': None, '2010': 94.0, '2011': 94.0, '2012': 94.0, '2013': 94.0, '2014': 94.0, '2015': 100.0, '2016': 100.0, '2017': 97.0, '2018': 100.0, '2019': 100.0, '2020': 100.0}, {'Indicator': 'Immunization coverage rate (percent)', 'Country': 'United Arab Emirates', 'Age': 'Age not available', 'Sex': 'Both sexes', 'Area': 'Area Total', 'Nationality': 'Nationality Total', 'Immunization': 'Hepatitis immunization', 'Contraception method': 'Method NA', '2000': None, '2001': None, '2002': None, '2003': None, '2004': None, '2005': None, '2006': None, '2007': None, '2008': None, '2009': None, '2010': None, '2011': None, '2012': None, '2013': None, '2014': None, '2015': None, '2016': None, '2017': None, '2018': None, '2019': None, '2020': None}, {'Indicator': 'Immunization coverage rate (percent)', 'Country': 'United Arab Emirates', 'Age': 'Age not available', 'Sex': 'Both sexes', 'Area': 'Area Total', 'Nationality': 'Nationality Total', 'Immunization': 'Measles immunization', 'Contraception method': 'Method NA', '2000': None, '2001': None, '2002': None, '2003': None, '2004': None, '2005': None, '2006': None, '2007': None, '2008': None, '2009': None, '2010': 94.0, '2011': 94.0, '2012': 94.0, '2013': 94.0, '2014': 94.0, '2015': 100.0, '2016': 100.0, '2017': 99.0, '2018': 100.0, '2019': 100. ...
# Finished document:  2
# Starting with Document:  3
# Downloading Data
# [{'Indicator': 'Net enrolment rate in primary education (percent)', 'Country': 'United Arab Emirates', 'Age': '5-14 years', 'Sex': 'Both sexes', 'Education level': 'Primary', 'Sector': 'Sector NA', 'Nationality': 'Nationality Total', '2000': None, '2001': None, '2002': None, '2003': None, '2004': None, '2005': None, '2006': None, '2007': None, '2008': None, '2009': None, '2010': None, '2011': None, '2012': None, '2013': 85.56, '2014': 90.221, '2015': 93.74, '2016': 94.55, '2017': 95.03, '2018': None, '2019': None}, {'Indicator': 'Net enrolment rate in primary education (percent)', 'Country': 'United Arab Emirates', 'Age': '5-14 years', 'Sex': 'Female', 'Education level': 'Primary', 'Sector': 'Sector NA', 'Nationality': 'Nationality Total', '2000': None, '2001': None, '2002': None, '2003': None, '2004': None, '2005': None, '2006': None, '2007': 87.06437, '2008': None, '2009': None, '2010': None, '2011': None, '2012': 87.45417, '2013': 86.8, '2014': None, '2015': None, '2016': None, '2017': None, '2018': None, '2019': None}, {'Indicator': 'Net enrolment rate in primary education (percent)', 'Country': 'United Arab Emirates', 'Age': '5-14 years', 'Sex': 'Male', 'Education level': 'Primary', 'Sector': 'Sector NA', 'Nationality': 'Nationality Total', '2000': None, '2001': None, '2002': None, '2003': None, '2004': None, '2005': None, '2006': None, '2007': None, '2008': None, '2009': None, '2010': None, '2011': None, '2012': None, '2013': 84.4, '2014': None, '2015': None, '2016': None, '2017': None, '2018': None, '2019': None}, {'Indicator': 'Net enrolment rate in secondary education (percent)', 'Country': 'United Arab Emirates', 'Age': '15-17 years', 'Sex': 'Both sexes', 'Education level': 'Secondary', 'Sector': 'Sector NA', 'Nationality': 'Nationality Total', '2000': None, '2001': None, '2002': None, '2003': None, '2004': None, '2005': None, '2006': None, '2007': None, '2008': None, '2009': None, '2010': None, '2011': None, '2012': None, '2013': None, '2014': None, '2015': None, '2016': 87.07, '2017': 92.8, '2018': None, '2019': None}, {'Indicator': 'Net enrolment rate in secondary education (percent)', 'Country': 'United Arab Emirates', 'Age': '15-17 years', 'Sex': 'Female', 'Education level': 'Secondary', 'Sector': 'Sector NA', 'Nationality': 'Nationality Total', '2000': None, '2001': None, '2002': None, '2003': None, '2004': None, '2005': None, '2006': None, '2007': None, '2008': None, '2009': None, '2010': None, '2011': None, '2012': None, '2013': None, '2014': None, '2015': None, '2016': 85.88, '2017': 90.33, '2018': None, '2019': None}, {'Indicator': 'Net enrolment rate in secondary education (percent)', 'Country': 'United Arab Emirates', 'Age': '15-17 years', 'Sex': 'Male', 'Education level': 'Secondary', 'Sector': 'Sector NA', 'Nationality': 'Nationality Total', '2000': None, '2001': None, '2002': None, '2003': None, '2004': None, '2005': None, '2006': None, '2007': None, '2008': None, '2009': None, '2010': None, '2011': None, '2012': None, '2013': None, '2014': None, '2015': None, '2016': 88.24077, '2017': 95.1514, '2018': None, '2019': None}, {'Indicator': 'Gross enrolment ratio in primary education (percent)', 'Country': 'United Arab Emirates', 'Age': '5-14 years', 'Sex': 'Both sexes', 'Education level': 'Primary', 'Sector': 'Sector NA', 'Nationality': 'Nationality Total', '2000': None, '2001': None, '2002': None, '2003': None, '2004': None, '2005': None, '2006': None, '2007': None, '2008': None, '2009': None, '2010': None, '2011': None, '2012': None, '2013': 98.67, '2014': 103.07, '2015': 111.54, '2016': 108.67, '2017': 108.4, '2018': None, '2019': None}, {'Indicator': 'Gross enrolment ratio in primary education (percent)', 'Country': 'United Arab Emirates', 'Age': '5-14 years', 'Sex': 'Female', 'Education level': 'Primary', 'Sector': 'Sector NA', 'Nationality': 'Nationality Total', '2000': None, '2001': None, '2002': None, '2003': None, '2004': None, '2005': None, '2006': None, '2007': None, '2008': None, '2009': None, ...
# Finished document:  3
# Starting with Document:  4
# Downloading Data
